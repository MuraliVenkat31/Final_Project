# %%
import pandas as pd

# %%
loan_dir = "/content/drive/MyDrive/Final Project/loan_data.csv"

# %%
data = pd.read_csv(loan_dir)

# %%
data.head(3)
# Out:
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE_x CODE_GENDER FLAG_OWN_CAR  \
# 0      100002       1           Cash loans           M            N
# 1      100003       0           Cash loans           F            N
# 2      100003       0           Cash loans           F            N
#
#   FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT_x  \
# 0               Y             0          202500.0      406597.5
# 1               N             0          270000.0     1293502.5
# 2               N             0          270000.0     1293502.5
#
#    AMT_ANNUITY_x  ...  NAME_SELLER_INDUSTRY CNT_PAYMENT NAME_YIELD_GROUP  \
# 0        24700.5  ...       Auto technology        24.0       low_normal
# 1        35698.5  ...                   XNA        12.0       low_normal
# 2        35698.5  ...             Furniture         6.0           middle
#
#           PRODUCT_COMBINATION DAYS_FIRST_DRAWING DAYS_FIRST_DUE  \
# 0     POS other with interest           365243.0         -565.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1413701 entries, 0 to 1413700
# Columns: 158 entries, SK_ID_CURR to NFLAG_INSURED_ON_APPROVAL
# dtypes: float64(80), int64(46), object(32)
# memory usage: 1.7+ GB

# %%
data.shape
# Out:
# (1413701, 158)

# %%
data.isnull().mean() * 100
# Out:
# SK_ID_CURR                    0.000000
# TARGET                        0.000000
# NAME_CONTRACT_TYPE_x          0.000000
# CODE_GENDER                   0.000000
# FLAG_OWN_CAR                  0.000000
#                                ...
# DAYS_FIRST_DUE               39.690571
# DAYS_LAST_DUE_1ST_VERSION    39.690571
# DAYS_LAST_DUE                39.690571
# DAYS_TERMINATION             39.690571
# NFLAG_INSURED_ON_APPROVAL    39.690571
# Length: 158, dtype: float64

# %%
# This will drop columns where more than 50% of the values are null.

data = data.dropna(axis=1)

# %%
data.shape
# Out:
# (1413701, 77)

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.describe()
# Out:
#          SK_ID_CURR        TARGET  CNT_CHILDREN  AMT_INCOME_TOTAL  \
# count  1.413701e+06  1.413701e+06  1.413701e+06      1.413701e+06
# mean   2.784813e+05  8.655296e-02  4.048933e-01      1.733160e+05
# std    1.028118e+05  2.811789e-01  7.173454e-01      1.985734e+05
# min    1.000020e+05  0.000000e+00  0.000000e+00      2.565000e+04
# 25%    1.893640e+05  0.000000e+00  0.000000e+00      1.125000e+05
# 50%    2.789920e+05  0.000000e+00  0.000000e+00      1.575000e+05
# 75%    3.675560e+05  0.000000e+00  1.000000e+00      2.070000e+05
# max    4.562550e+05  1.000000e+00  1.900000e+01      1.170000e+08
#
#        AMT_CREDIT_x  REGION_POPULATION_RELATIVE    DAYS_BIRTH  DAYS_EMPLOYED  \
# count  1.413701e+06                1.413701e+06  1.413701e+06   1.413701e+06
# mean   5.875537e+05                2.074985e-02 -1.632105e+04   6.870203e+04
# std    3.849173e+05                1.334702e-02  4.344557e+03   1.452777e+05
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1413701 entries, 0 to 1413700
# Data columns (total 77 columns):
#  #   Column                        Non-Null Count    Dtype
# ---  ------                        --------------    -----
#  0   SK_ID_CURR                    1413701 non-null  int64
#  1   TARGET                        1413701 non-null  int64
#  2   NAME_CONTRACT_TYPE_x          1413701 non-null  object
#  3   CODE_GENDER                   1413701 non-null  object
#  4   FLAG_OWN_CAR                  1413701 non-null  object
#  5   FLAG_OWN_REALTY               1413701 non-null  object
#  6   CNT_CHILDREN                  1413701 non-null  int64
#  7   AMT_INCOME_TOTAL              1413701 non-null  float64
#  8   AMT_CREDIT_x                  1413701 non-null  float64
#  9   NAME_INCOME_TYPE              1413701 non-null  object
#  10  NAME_EDUCATION_TYPE           1413701 non-null  object
#  11  NAME_FAMILY_STATUS            1413701 non-null  object
# ...

# %%
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.preprocessing import LabelEncoder

# %%
string_cols = data.select_dtypes(include=['object']).columns

# %%
# create a LabelEncoder object
le = LabelEncoder()

# encode string columns
data[string_cols] = data[string_cols].apply(le.fit_transform)

# %%
data.head(2)
# Out:
#    SK_ID_CURR  TARGET  NAME_CONTRACT_TYPE_x  CODE_GENDER  FLAG_OWN_CAR  \
# 0      100002       1                     0            1             0
# 1      100003       0                     0            0             0
#
#    FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT_x  \
# 0                1             0          202500.0      406597.5
# 1                0             0          270000.0     1293502.5
#
#    NAME_INCOME_TYPE  ...  NAME_PAYMENT_TYPE  CODE_REJECT_REASON  \
# 0                 6  ...                  3                   7
# 1                 3  ...                  3                   7
#
#    NAME_CLIENT_TYPE  NAME_GOODS_CATEGORY  NAME_PORTFOLIO  NAME_PRODUCT_TYPE  \
# 0                 0                   24               3                  0
# 1                 2                   26               2                  2
#
#    CHANNEL_TYPE  SELLERPLACE_AREA  NAME_SELLER_INDUSTRY  NAME_YIELD_GROUP
# ...

# %%
correlation = data.corr()['TARGET']
correlation
# Out:
# SK_ID_CURR             -0.001246
# TARGET                  1.000000
# NAME_CONTRACT_TYPE_x   -0.032342
# CODE_GENDER             0.052810
# FLAG_OWN_CAR           -0.014511
#                           ...
# NAME_PRODUCT_TYPE       0.001476
# CHANNEL_TYPE           -0.028832
# SELLERPLACE_AREA       -0.002539
# NAME_SELLER_INDUSTRY    0.020053
# NAME_YIELD_GROUP       -0.033715
# Name: TARGET, Length: 77, dtype: float64

# %%
correlation = correlation.abs()
correlation
# Out:
# SK_ID_CURR              0.001246
# TARGET                  1.000000
# NAME_CONTRACT_TYPE_x    0.032342
# CODE_GENDER             0.052810
# FLAG_OWN_CAR            0.014511
#                           ...
# NAME_PRODUCT_TYPE       0.001476
# CHANNEL_TYPE            0.028832
# SELLERPLACE_AREA        0.002539
# NAME_SELLER_INDUSTRY    0.020053
# NAME_YIELD_GROUP        0.033715
# Name: TARGET, Length: 77, dtype: float64

# %%
sorted_feature = correlation.sort_values(ascending=False)
sorted_feature
# Out:
# TARGET                         1.000000
# DAYS_BIRTH                     0.074866
# DAYS_LAST_PHONE_CHANGE         0.059721
# REGION_RATING_CLIENT_W_CITY    0.059700
# REGION_RATING_CLIENT           0.056932
#                                  ...
# FLAG_DOCUMENT_21               0.000431
# FLAG_DOCUMENT_12               0.000366
# NAME_CONTRACT_TYPE_y           0.000185
# FLAG_CONT_MOBILE               0.000059
# FLAG_MOBIL                          NaN
# Name: TARGET, Length: 77, dtype: float64

# %%
k_best = SelectKBest(score_func=f_classif, k=15)

# %%
val = data.drop("TARGET", axis=1)
tar = data['TARGET']

# %%
x_new = k_best.fit_transform(val,tar)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_selection/_univariate_selection.py:112: UserWarning: Features [17] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx, UserWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_selection/_univariate_selection.py:113: RuntimeWarning: invalid value encountered in divide
#   f = msb / msw

# %%
selected_indices = k_best.get_support(indices=True)

# %%
selected_features = data.columns[selected_indices]
selected_features
# Out:
# Index(['NAME_CONTRACT_TYPE_x', 'AMT_CREDIT_x', 'NAME_INCOME_TYPE',
#        'REGION_POPULATION_RELATIVE', 'DAYS_BIRTH', 'DAYS_EMPLOYED',
#        'DAYS_REGISTRATION', 'FLAG_MOBIL', 'CNT_FAM_MEMBERS',
#        'REGION_RATING_CLIENT', 'REG_CITY_NOT_LIVE_CITY', 'ORGANIZATION_TYPE',
#        'FLAG_DOCUMENT_2', 'NAME_CASH_LOAN_PURPOSE', 'NAME_PAYMENT_TYPE'],
#       dtype='object')

# %%
data01 = data[['NAME_CONTRACT_TYPE_x', 'AMT_CREDIT_x', 'NAME_INCOME_TYPE',
       'REGION_POPULATION_RELATIVE', 'DAYS_BIRTH', 'DAYS_EMPLOYED',
       'DAYS_REGISTRATION', 'FLAG_MOBIL', 'CNT_FAM_MEMBERS',
       'REGION_RATING_CLIENT', 'REG_CITY_NOT_LIVE_CITY', 'ORGANIZATION_TYPE',
       'FLAG_DOCUMENT_2', 'NAME_CASH_LOAN_PURPOSE', 'NAME_PAYMENT_TYPE']]

# %%
data01.head(2)
# Out:
#    NAME_CONTRACT_TYPE_x  AMT_CREDIT_x  NAME_INCOME_TYPE  \
# 0                     0      406597.5                 6
# 1                     0     1293502.5                 3
#
#    REGION_POPULATION_RELATIVE  DAYS_BIRTH  DAYS_EMPLOYED  DAYS_REGISTRATION  \
# 0                    0.018801       -9461           -637            -3648.0
# 1                    0.003541      -16765          -1188            -1186.0
#
#    FLAG_MOBIL  CNT_FAM_MEMBERS  REGION_RATING_CLIENT  REG_CITY_NOT_LIVE_CITY  \
# 0           1              1.0                     2                       0
# 1           1              2.0                     1                       0
#
#    ORGANIZATION_TYPE  FLAG_DOCUMENT_2  NAME_CASH_LOAN_PURPOSE  \
# 0                  5                0                      23
# 1                 39                0                      24
#
#    NAME_PAYMENT_TYPE
# 0                  3
# 1                  3
